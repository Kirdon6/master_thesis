# %%
import yaml
from benchmark import run_benchmark_from_notebook

# %%
# Path to your configuration file
config_path = "baseline_mlp_config.yaml"

# Run the benchmark
results = run_benchmark_from_notebook(config_path, use_cpu=False)

# Display the results
results
# Out:
# Using device: cuda
# Validating dataset (max atoms: 100)...
# Dataset validation successful - all structures have appropriate atom counts.
# Dataset: CHILI-3K
# Task: AbsPositionRegressionxPDF
# Model: MLP
# Training samples: 2544
# Validation samples: 318
# Test samples: 318
#
# Running with seed: 42
# Epoch: 1/100, Train Loss: 10.1037, Val PositionMAE: 4.9660
# Epoch: 2/100, Train Loss: 10.1665, Val PositionMAE: 5.0676
# Epoch: 3/100, Train Loss: 10.0743, Val PositionMAE: 4.8659
# Epoch: 4/100, Train Loss: 10.1597, Val PositionMAE: 4.8868
# Epoch: 5/100, Train Loss: 10.1320, Val PositionMAE: 4.8822
# Epoch: 6/100, Train Loss: 10.0960, Val PositionMAE: 4.9522
# Epoch: 7/100, Train Loss: 10.0901, Val PositionMAE: 5.4041
# Epoch: 8/100, Train Loss: 10.0049, Val PositionMAE: 5.0320
# Epoch: 9/100, Train Loss: 10.0607, Val PositionMAE: 9.0661
# Epoch: 10/100, Train Loss: 10.0710, Val PositionMAE: 4.8722
# Epoch: 11/100, Train Loss: 10.1316, Val PositionMAE: 4.8963
# ...

# %%
# Path to your configuration file
config_path = "CHILI_mlp_config.yaml"

# Run the benchmark
results = run_benchmark_from_notebook(config_path, use_cpu=False)

# Display the results
results
# Out:
# Using device: cuda
# Validating dataset (max atoms: 100)...
# Dataset validation successful - all structures have appropriate atom counts.
# Dataset: CHILI-3K
# Task: AbsPositionRegressionxPDF
# Model: MLP
# Training samples: 2544
# Validation samples: 318
# Test samples: 318
#
# Running with seed: 42
# Epoch: 1/100, Train Loss: 10.1648, Val PositionMAE: 4.9127
# Epoch: 2/100, Train Loss: 10.1280, Val PositionMAE: 4.9926
# Epoch: 3/100, Train Loss: 10.1258, Val PositionMAE: 4.9433
# Epoch: 4/100, Train Loss: 10.0894, Val PositionMAE: 4.9534
# Epoch: 5/100, Train Loss: 10.1140, Val PositionMAE: 4.9858
# Epoch: 6/100, Train Loss: 10.1012, Val PositionMAE: 4.9703
# Epoch: 7/100, Train Loss: 10.0999, Val PositionMAE: 4.9573
# Epoch: 8/100, Train Loss: 10.0951, Val PositionMAE: 4.9449
# Epoch: 9/100, Train Loss: 10.1291, Val PositionMAE: 4.9459
# Epoch: 10/100, Train Loss: 10.1046, Val PositionMAE: 4.9496
# Epoch: 11/100, Train Loss: 10.1222, Val PositionMAE: 4.9735
# ...

# %%
# Path to your configuration file
config_path = "CHILI_trivial.yaml"

# Run the benchmark
results = run_benchmark_from_notebook(config_path, use_cpu=False)

# Display the results
results
