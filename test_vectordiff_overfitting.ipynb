# %%
from test_vectordiff_overfitting import benchmark_overfitting
benchmark_overfitting()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from test_vectordiff_overfitting import benchmark_overfitting
#       2 benchmark_overfitting()
#
# File c:\Users\toman\Documents\Ondro\master_thesis\test_vectordiff_overfitting.py:11
#       9 from CHILI_centralAtoms import CHILI
#      10 from vector_diff import VectorDiffusion
# ---> 11 from reporter import Reporter
#      12 from benchmark_tasks_utils import pos_abs_padded, position_MAE
#      14 def create_small_dataset(dataset, num_samples=5):
#
# File c:\Users\toman\Documents\Ondro\master_thesis\reporter.py:10
#       6 import os
#       7 from vector_diff import VectorDiffusion  # Import VectorDiffusion
# ---> 10 class Reporter:
#      11     """
#      12     Reporter class for visualizing diffusion processes during training.
#      13
#    (...)
# ...
