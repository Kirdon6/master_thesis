# %%
from test_vectordiff_overfitting import run_benchmark_overfitting

# %%
run_benchmark_overfitting(config_path='./configs/vector_diff_config.yaml')
# Out:
# Using device: cuda
# Created small dataset with 5 samples
# Validating dataset (max atoms: 100)...
# Dataset validation successful - all structures have appropriate atom counts.
# Dataset: CHILI-3K (Small subset for overfitting test)
# Task: AbsPositionRegressionxPDF
# Model: VectorDiffusion
# Training samples: 4
# Validation samples: 1
#
# Running with seed: 42
#
# Model Summary for VectorDiffusion:
# Total trainable parameters: 12,433,667 (12434k)
# Model architecture:
# VectorDiffusion(
#   (encoder): Encoder(
#     (encoder): Sequential(
#       (0): Linear(in_features=6000, out_features=256, bias=True)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.1, inplace=False)
#       (4): Linear(in_features=256, out_features=256, bias=True)
#       (5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): Identity()
#       (7): Identity()
#     )
#   )
# ...

# %%
run_benchmark_overfitting(config_path='./configs/vector_diff_small_config.yaml')
# Out:
# Using device: cuda
# Created small dataset with 5 samples
# Validating dataset (max atoms: 100)...
# Dataset validation successful - all structures have appropriate atom counts.
# Dataset: CHILI-3K (Small subset for overfitting test)
# Task: AbsPositionRegressionxPDF
# Model: VectorDiffusion
# Training samples: 4
# Validation samples: 1
#
# Running with seed: 42
#
# Model Summary for VectorDiffusion:
# Total trainable parameters: 1,068,611 (1069k)
# Model architecture:
# VectorDiffusion(
#   (encoder): Encoder(
#     (encoder): Sequential(
#       (0): Linear(in_features=6000, out_features=64, bias=True)
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.1, inplace=False)
#       (4): Linear(in_features=64, out_features=64, bias=True)
#       (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): Identity()
#       (7): Identity()
#     )
#   )
# ...

# %%
run_benchmark_overfitting(config_path='./configs/vector_diff_tiny_config.yaml')
# Out:
# Using device: cuda
# Created small dataset with 5 samples
# Validating dataset (max atoms: 100)...
# Dataset validation successful - all structures have appropriate atom counts.
# Dataset: CHILI-3K (Small subset for overfitting test)
# Task: AbsPositionRegressionxPDF
# Model: VectorDiffusion
# Training samples: 4
# Validation samples: 1
#
# Running with seed: 42
#
# Model Summary for VectorDiffusion:
# Total trainable parameters: 364,323 (364k)
# Model architecture:
# VectorDiffusion(
#   (encoder): Encoder(
#     (encoder): Sequential(
#       (0): Linear(in_features=6000, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.1, inplace=False)
#       (4): Linear(in_features=32, out_features=32, bias=True)
#       (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): Identity()
#       (7): Identity()
#     )
#   )
# ...

# %%
run_benchmark_overfitting(config_path='./configs/vector_diff_tiny40_bigT_config.yaml')
# Out:
# Using device: cuda
# Created small dataset with 5 samples
# Validating dataset (max atoms: 100)...
# Dataset validation successful - all structures have appropriate atom counts.
# Dataset: CHILI-3K (Small subset for overfitting test)
# Task: AbsPositionRegressionxPDF
# Model: VectorDiffusion
# Training samples: 4
# Validation samples: 1
#
# Running with seed: 42
#
# Model Summary for VectorDiffusion:
# Total trainable parameters: 508,523 (509k)
# Model architecture:
# VectorDiffusion(
#   (encoder): Encoder(
#     (encoder): Sequential(
#       (0): Linear(in_features=6000, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.1, inplace=False)
#       (4): Linear(in_features=40, out_features=40, bias=True)
#       (5): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): Identity()
#       (7): Identity()
#     )
#   )
# ...

# %%
run_benchmark_overfitting(config_path='./configs/vector_diff_tiny40_smallT_config.yaml')
# Out:
# Using device: cuda
# Created small dataset with 5 samples
# Validating dataset (max atoms: 100)...
# Dataset validation successful - all structures have appropriate atom counts.
# Dataset: CHILI-3K (Small subset for overfitting test)
# Task: AbsPositionRegressionxPDF
# Model: VectorDiffusion
# Training samples: 4
# Validation samples: 1
#
# Running with seed: 42
#
# Model Summary for VectorDiffusion:
# Total trainable parameters: 1,068,611 (1069k)
# Model architecture:
# VectorDiffusion(
#   (encoder): Encoder(
#     (encoder): Sequential(
#       (0): Linear(in_features=6000, out_features=64, bias=True)
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.1, inplace=False)
#       (4): Linear(in_features=64, out_features=64, bias=True)
#       (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): Identity()
#       (7): Identity()
#     )
#   )
# ...

# %%
run_benchmark_overfitting(config_path='./configs/vector_diff_config_bigT.yaml')
